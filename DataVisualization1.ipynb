# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Student1.csv')

# %%
df
# Out:
#   Student_Name  Marks  Age  Contact No.  Study_Hours
# 0      Rishabh     85   19   9843432442            4
# 1        Mohit     78   20   8843989344            5
# 2         Aman     93   19   9848394223            6
# 3         John     89   20   9432293289            5

# %%
plt.pie(df.Marks,labels=df.Student_Name,explode=[0,0,0,0.1],shadow=True,autopct='%.2f%%')
plt.show()

# %%
plt.pie(df.Study_Hours,labels=df.Student_Name,explode=[0,0,0,0.1],shadow=True,autopct='%.2f%%')
plt.show()
